# %%
import pandas as pd
import numpy as np
import statsmodels.api as sm
import statsmodels.stats.diagnostic as diagnostic 
import matplotlib.pyplot as plt

plt.style.use('seaborn')

# %%
dataset = pd.read_csv("dataset/adjusted.csv")
dataset.shape
# Out:
# (54, 12)

# %%
plt.hist(dataset["screen_time"], bins=20, facecolor="blue", alpha=0.7)
plt.xlabel("Screen Time")
plt.ylabel("Count")
plt.show()

# %%
plt.hist(dataset["sleep_time"], bins=20, facecolor="blue", alpha=0.7)
plt.xlabel("Sleep Time")
plt.ylabel("Count")
plt.show()

# %%
encoded_dataset = pd.read_csv("dataset/encoded.csv")
encoded_dataset.shape
# Out:
# (54, 21)

# %%
## create scatter plot of sleep time and screen time.

plt.scatter(x=encoded_dataset["screen_time"], y=encoded_dataset["sleep_time"])
plt.xlabel("Screen Time")
plt.ylabel("Sleep Time")
plt.show()

# %%
regression = sm.OLS.from_formula("sleep_time ~ screen_time + age + sex + occupation", encoded_dataset).fit()

regression.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             sleep_time   R-squared:                       0.188
# Model:                            OLS   Adj. R-squared:                 -0.025
# Method:                 Least Squares   F-statistic:                    0.8813
# Date:                Mon, 02 Nov 2020   Prob (F-statistic):              0.565
# Time:                        22:14:01   Log-Likelihood:                -36.128
# No. Observations:                  54   AIC:                             96.26
# Df Residuals:                      42   BIC:                             120.1
# Df Model:                          11
# Covariance Type:            nonrobust
# =========================================================================================================
#                                             coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------------------
# Intercept                                 1.3242      0.423      3.129      0.003       0.470       2.178
# occupation[T.Media Massa]                -0.2185      0.438     -0.499      0.620      -1.102       0.665
# occupation[T.Otomasi industri]            0.3944      0.593      0.665      0.510      -0.802       1.591
# occupation[T.Pendidikan]                 -0.3518      0.298     -1.179      0.245      -0.954       0.250
# occupation[T.Perbankan]                   0.4035      0.415      0.972      0.337      -0.435       1.241
# occupation[T.Seni Kreatif dan Desain]    -0.1624      0.310     -0.523      0.604      -0.789       0.464
# occupation[T.Sosial]                     -0.6976      0.579     -1.204      0.235      -1.867       0.472
# occupation[T.Teknologi Informasi]         0.0062      0.244      0.025      0.980      -0.487       0.499
# occupation[T.Telekomunikasi]              0.3524      0.593      0.595      0.555      -0.844       1.549
# screen_time                               0.0919      0.092      1.000      0.323      -0.094       0.278
# age                                       0.0420      0.131      0.321      0.750      -0.222       0.306
# sex                                       0.0975      0.178      0.549      0.586      -0.261       0.456
# ==============================================================================
# Omnibus:                        3.062   Durbin-Watson:                   2.457
# Prob(Omnibus):                  0.216   Jarque-Bera (JB):                2.950
# Skew:                          -0.536   Prob(JB):                        0.229
# Kurtosis:                       2.599   Cond. No.                         35.1
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """
