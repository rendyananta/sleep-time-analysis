# %%
import pandas as pd
import numpy as np
import statsmodels.api as sm
import statsmodels.stats.diagnostic as diagnostic 
import matplotlib.pyplot as plt

plt.style.use('seaborn')

# %%
dataset = pd.read_csv("dataset/adjusted.csv")
dataset.shape
# Out:
# (46, 12)

# %%
plt.hist(dataset["screen_time"], bins=20, facecolor="blue", alpha=0.7)
plt.xlabel("Screen Time")
plt.ylabel("Count")
plt.show()

# %%
plt.hist(dataset["sleep_time"], bins=20, facecolor="blue", alpha=0.7)
plt.xlabel("Sleep Time")
plt.ylabel("Count")
plt.show()

# %%
encoded_dataset = pd.read_csv("dataset/encoded.csv")
encoded_dataset.shape
# Out:
# (46, 20)

# %%
## create scatter plot of sleep time and screen time.

plt.scatter(x=encoded_dataset["screen_time"], y=encoded_dataset["sleep_time"])
plt.xlabel("Screen Time")
plt.ylabel("Sleep Time")
plt.show()

# %%
regression = sm.OLS.from_formula("sleep_time ~ screen_time + occupation + difference_before_pandemic", encoded_dataset).fit()

regression.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:             sleep_time   R-squared:                       0.270
# Model:                            OLS   Adj. R-squared:                  0.083
# Method:                 Least Squares   F-statistic:                     1.440
# Date:                Sat, 07 Nov 2020   Prob (F-statistic):              0.209
# Time:                        17:48:09   Log-Likelihood:                -28.475
# No. Observations:                  45   AIC:                             76.95
# Df Residuals:                      35   BIC:                             95.02
# Df Model:                           9
# Covariance Type:            nonrobust
# ...
#                                             coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------------------
# ...
